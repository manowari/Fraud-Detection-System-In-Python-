# %%
import main.main as run

run.main()
# Out:
#                Time            V1            V2            V3            V4  \
# count  71201.000000  71201.000000  71201.000000  71201.000000  71201.000000
# mean   35003.011053     -0.250255     -0.024217      0.680096      0.168842
# std    14505.929013      1.878539      1.662448      1.417291      1.374936
# min        0.000000    -56.407510    -72.715728    -33.680984     -5.172595
# 25%    28928.000000     -1.010040     -0.593532      0.193736     -0.725612
# 50%    38190.000000     -0.247750      0.072087      0.770240      0.187161
# 75%    45959.000000      1.153477      0.727626      1.402113      1.052382
# max    54201.000000      1.960497     18.902453      4.226108     16.715537
#
#                  V5            V6            V7            V8            V9  \
# count  71201.000000  71201.000000  71201.000000  71201.000000  71201.000000
# mean      -0.270857      0.099992     -0.114945      0.056809      0.016231
# ...
